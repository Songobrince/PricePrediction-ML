# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\ERIC\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#  load the data
data = pd.read_csv('pyrethrum_price.csv')
data.describe()
# Out:
#                 Fp           RI           Py           KT           Pd
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
print(data.columns)
pyrethrum_data = data.drop(['RI', 'Py', 'KT', 'Pd'], axis=1)
# Out:
# Index(['Date', 'Fp', 'RI', 'Py', 'KT', 'Pd'], dtype='object')

# %%
# Assuming you want to change the name 'RI' to 'NewColumnName'
pyrethrum_data.rename(columns={'Fp': 'Price'}, inplace=True)
pyrethrum_data
# Out:
#            Date        Price
# 0      1/2/2008  1447.160034
# 1      1/3/2008  1447.160034
# 2      1/4/2008  1411.630005
# 3      1/7/2008  1416.180054
# 4      1/8/2008  1390.189941
# ...         ...          ...
# 2285   5/8/2018  2671.919922
# 2286   5/9/2018  2697.790039
# 2287  5/10/2018  2723.070068
# 2288  5/14/2018  2730.129883
# 2289  5/16/2018  2725.780029
#
# [2290 rows x 2 columns]

# %%
pyrethrum_data['Altitude'] = None
pyrethrum_data['Rainfall'] = None
pyrethrum_data['Pyrethrin_Content'] = None
pyrethrum_data['Altitude'] = None

pyrethrum_data['Temperature'] = None
pyrethrum_data['Humidity'] = None
pyrethrum_data['Soil_ph'] = None

# %%
pyrethrum_data
# Out:
#            Date        Price Altitude Rainfall Pyrethrin_Content Temperature  \
# 0      1/2/2008  1447.160034     None     None              None        None
# 1      1/3/2008  1447.160034     None     None              None        None
# 2      1/4/2008  1411.630005     None     None              None        None
# 3      1/7/2008  1416.180054     None     None              None        None
# 4      1/8/2008  1390.189941     None     None              None        None
# ...         ...          ...      ...      ...               ...         ...
# 2285   5/8/2018  2671.919922     None     None              None        None
# 2286   5/9/2018  2697.790039     None     None              None        None
# 2287  5/10/2018  2723.070068     None     None              None        None
# 2288  5/14/2018  2730.129883     None     None              None        None
# 2289  5/16/2018  2725.780029     None     None              None        None
#
#      Humidity Soil_ph
# ...

# %%
pyrethrum_data.describe()
# Out:
#              Price
# count  2290.000000
# mean   1654.315776
# std     519.111540
# min     676.530029
# 25%    1239.874969
# 50%    1551.434998
# 75%    2073.010070
# max    2872.870117

# %%
import random

max_price = 2872
optimal_altitude = 2130
min_altitude = 1980
max_altitude = 2500
constant = optimal_altitude / max_altitude

# Custom function to calculate altitude
def calculate_altitude(price):
    threshold = price / max_price
    altitude = max_altitude * threshold * constant
    return altitude

def calculate_temperature(price):
    threshold = price / max_price
    temperature  = 35 * threshold 
    return temperature

def calculate_humidity(price):
    threshold = price / max_price
    humidity = 80 * threshold 
    return humidity


def calculate_rainfall(price):
    threshold = price / max_price
    altitude = 1226 * threshold
    return altitude

def calculate_pyrethrum_content(price):
    threshold = price / max_price
    PC  = 2.1 * threshold
    return PC

def calculate_pyrethrum_content(price):
    threshold = price / max_price
    PC  = 2.1 * threshold
    return PC

def calculate_pH(price):
    threshold = price / max_price
    PC  = threshold
    return PC


# Apply the function to create a new column 'Altitude'
pyrethrum_data['Altitude'] = pyrethrum_data['Price'].apply(calculate_altitude)
pyrethrum_data['Rainfall'] = pyrethrum_data['Price'].apply(calculate_rainfall)
pyrethrum_data['Pyrethrin_Content'] = pyrethrum_data['Price'].apply(calculate_pyrethrum_content)
pyrethrum_data['Temperature'] = pyrethrum_data['Price'].apply(calculate_temperature)
pyrethrum_data['Humidity'] = pyrethrum_data['Price'].apply(calculate_humidity)

pyrethrum_data.head(-50)
# Out:
#            Date        Price     Altitude     Rainfall  Pyrethrin_Content  \
# 0      1/2/2008  1447.160034  1073.276766   617.763998           1.058160
# 1      1/3/2008  1447.160034  1073.276766   617.763998           1.058160
# 2      1/4/2008  1411.630005  1046.926153   602.596931           1.032181
# 3      1/7/2008  1416.180054  1050.300667   604.539257           1.035508
# 4      1/8/2008  1390.189941  1031.025270   593.444592           1.016504
# ...         ...          ...          ...          ...                ...
# 2235  2/16/2018  2732.219971  2026.333056  1166.330670           1.997793
# 2236  2/20/2018  2716.260010  2014.496456  1159.517678           1.986123
# 2237  2/21/2018  2701.330078  2003.423770  1153.144386           1.975207
# 2238  2/22/2018  2703.959961  2005.374205  1154.267031           1.977129
# 2239  2/23/2018  2747.300049  2037.517098  1172.768057           2.008820
#
#       Temperature   Humidity   Soil_ph
# 0       17.636003  40.310864  5.085425
# ...

# %%
newdata = pyrethrum_data.drop('Date' ,axis= 1)
newdata
# Out:
#             Price     Altitude     Rainfall  Pyrethrin_Content  Temperature  \
# 0     1447.160034  1073.276766   617.763998           1.058160    17.636003
# 1     1447.160034  1073.276766   617.763998           1.058160    17.636003
# 2     1411.630005  1046.926153   602.596931           1.032181    17.203012
# 3     1416.180054  1050.300667   604.539257           1.035508    17.258462
# 4     1390.189941  1031.025270   593.444592           1.016504    16.941730
# ...           ...          ...          ...                ...          ...
# 2285  2671.919922  1981.611920  1140.589772           1.953702    32.561698
# 2286  2697.790039  2000.798323  1151.633213           1.972618    32.876968
# 2287  2723.070068  2019.547091  1162.424757           1.991103    33.185046
# 2288  2730.129883  2024.782956  1165.438453           1.996265    33.271081
# 2289  2725.780029  2021.556916  1163.581586           1.993084    33.218071
#
#        Humidity   Soil_ph
# 0     40.310864  5.085425
# ...

# %%
# // split

# %%
# Out:
#              Price     Altitude     Rainfall  Pyrethrin_Content  Temperature  \
# count  2290.000000  2290.000000  2290.000000        2290.000000  2290.000000
# mean   1654.315776  1226.912467   706.194687           1.209632    20.160533
# std     519.111540   384.995676   221.598450           0.379573     6.326220
# min     676.530029   501.744067   288.797290           0.494677     8.244621
# 25%    1239.874969   919.545155   529.278103           0.906594    15.109897
# 50%    1551.434998  1150.611610   662.276917           1.134406    18.906764
# 75%    2073.010070  1537.434349   884.927001           1.515780    25.263006
# max    2872.870117  2130.645317  1226.371436           2.100636    35.010604
#
#           Humidity      Soil_ph
# count  2290.000000  2290.000000
# mean     46.081219     5.501854
# std      14.459931     0.867490
# min      18.844848     4.000203
# 25%      34.536907     4.749704
# 50%      43.215460     5.516861
# 75%      57.744013     6.267956
# ...

# %%
pyrethrum_data.tail(49)
# Out:
#            Date        Price     Altitude     Rainfall  Pyrethrin_Content  \
# 2241  2/27/2018  2744.280029  2035.277320  1171.478870           2.006611
# 2242  2/28/2018  2713.830078  2012.694313  1158.480388           1.984347
# 2243   3/1/2018  2677.669922  1985.876370  1143.044333           1.957906
# 2244   3/2/2018  2691.250000  1995.947946  1148.841400           1.967836
# 2245   3/5/2018  2720.939941  2017.967296  1161.515448           1.989545
# 2246   3/6/2018  2728.120117  2023.292427  1164.580523           1.994795
# 2247   3/7/2018  2726.800049  2022.313407  1164.017013           1.993830
# 2248   3/8/2018  2738.969971  2031.339150  1169.212112           2.002729
# 2249   3/9/2018  2786.570068  2066.641450  1189.531652           2.037534
# 2250  3/12/2018  2783.020020  2064.008580  1188.016206           2.034938
# 2251  3/13/2018  2765.310059  2050.874104  1180.456174           2.021989
# 2252  3/14/2018  2749.479980  2039.133829  1173.698627           2.010414
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
x = newdata.drop('Price', axis=1)
y = newdata['Price']  # Use square brackets to access the 'Price' column
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
# // create model  from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression

# Create a Linear Regression model
model = LinearRegression()

# Fit the model
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions on the test data
y_pred = model.predict(x_test)


# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 2.534372517767903e-13
# Mean Squared Error: 1.2803351661957855e-25
# R-squared: 1.0

# %%
# // save the model 
import pickle
with open('pyrethrum_prediction_price.pkl', 'wb') as files:
    pickle.dump(model,files)

# %%
# //load modeland test it
